# %%
import os
import yaml
import tqdm
import time
import torch
import random
import joblib
import logging
import subprocess
import pandas as pd
import multiprocessing as mp
from train_SL import trainer, mlp_trainer
from functools import partial

# %%
root = logging.getLogger()
root.setLevel(logging.DEBUG)
formatter = logging.Formatter('%(levelname)s:%(name)s:%(message)s')

# Stream output to stdout
ch = logging.StreamHandler()
ch.setLevel(logging.INFO)
ch.setFormatter(formatter)
root.addHandler(ch)

# %%
is_cuda = torch.cuda.is_available()
device = torch.device(torch.cuda.current_device()) if is_cuda else torch.device("cpu")

# %%
config = "config/SL.yml"

# %%
with open(config) as cf:
    conf = yaml.load(cf, Loader=yaml.FullLoader)

# %%
save_loc = conf["save_loc"]

# %%
data_seeds = list(range(100)) # refers to which split to take from GroupShuffleSplit(n_ensembles = 100)

# %%
model_seeds = random.sample(range(1, 5000), 100)

# %%
if not os.path.isfile("SL/ttt/seeds.pkl"):
    with open(f"{save_loc}/seeds.pkl", "wb") as fid:
        joblib.dump([data_seeds, model_seeds], fid)

# %%
with open(f"{save_loc}/seeds.pkl", "rb") as fid:
    data_seeds, model_seeds = joblib.load(fid)

# %%
def launch(config, model_seed, data_seed, model_type, save_path_extend):
    with open(config) as cf:
        conf = yaml.load(cf, Loader=yaml.FullLoader)
    save_loc = os.path.join(conf["save_loc"], f"{save_path_extend}/{data_seed}_{model_seed}")
    conf["data_seed"] = data_seed
    conf["model_seed"] = model_seed
    conf["save_loc"] = save_loc
    os.makedirs(save_loc, exist_ok = True)

    with open(os.path.join(save_loc, "model.yml"), "w") as fid:
        yaml.dump(conf, fid)
    if model_type == "mlp":
        result = mlp_trainer(conf, evaluate = True, verbose = False, device = device)
    else:
        result = trainer(conf, evaluate = True, verbose = False, device = device)
    result["data_seed"] = data_seed 
    result["model_seed"] = model_seed
    return result

def model_launch(model_seed, config, data_seed, model_type):
    seed_id = model_seeds.index(model_seed)
    worker_id = model_seeds.index(model_seed) % 8
    logging.info(f"Starting {seed_id} / {len(model_seeds)}, sleeping for {0.1*worker_id:.1f} s")
    #time.sleep(0.1 * worker_id)
    t0 = time.time()
    result = launch(config, model_seed, data_seed, model_type, "model")
    logging.info(f"Finished {seed_id} in {time.time()-t0}")
    return 

def data_launch(data_seed, config, model_seed, model_type):
    seed_id = data_seeds.index(data_seed)
    worker_id = data_seeds.index(data_seed) % 8
    logging.info(f"Starting {seed_id} / {len(data_seeds)}, sleeping for {0.1*worker_id:.1f} s")
    #time.sleep(0.1 * worker_id)
    t0 = time.time()
    result = launch(config, model_seed, data_seed, model_type, "data")
    logging.info(f"Finished {seed_id} in {time.time()-t0}")
    return

# %%
data_seed = data_seeds[0]
model_seed = model_seeds[0]

# %% [markdown]
# ### Create ensemble of model splits, with fixed train/valid/test data split

# %%
model_worker = partial(model_launch, 
                       config="config/SL-mlp.yml", 
                       model_type = "mlp", 
                       data_seed=data_seed)

# %%
#%%time
model_results = []
with mp.Pool(8) as p:
    for result in tqdm.tqdm(p.imap(model_worker, model_seeds), total = len(model_seeds)):
        model_results.append(result)
# Out:
# INFO:root:Starting 1 / 100, sleeping for 0.1 s
# INFO:root:Starting 0 / 100, sleeping for 0.0 s
# INFO:root:Starting 2 / 100, sleeping for 0.2 s
# INFO:root:Starting 3 / 100, sleeping for 0.3 s
# INFO:root:Starting 4 / 100, sleeping for 0.4 s
# INFO:root:Starting 5 / 100, sleeping for 0.5 s
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:root:Starting 7 / 100, sleeping for 0.7 s
# INFO:root:Starting 1 / 100, sleeping for 0.1 s
# INFO:root:Starting 6 / 100, sleeping for 0.6 s
# INFO:root:Starting 5 / 100, sleeping for 0.5 s
# INFO:root:Starting 2 / 100, sleeping for 0.2 s
# INFO:root:Starting 3 / 100, sleeping for 0.3 s
# INFO:root:Starting 7 / 100, sleeping for 0.7 s
# INFO:root:Starting 0 / 100, sleeping for 0.0 s
# INFO:root:Starting 4 / 100, sleeping for 0.4 s
# INFO:root:Starting 6 / 100, sleeping for 0.6 s
#   0%|          | 0/100 [00:01<?, ?it/s]INFO:root:Starting 8 / 100, sleeping for 0.0 s
# INFO:root:Starting 9 / 100, sleeping for 0.1 s
# INFO:root:Starting 10 / 100, sleeping for 0.2 s
# INFO:root:Starting 13 / 100, sleeping for 0.5 s
# INFO:root:Starting 14 / 100, sleeping for 0.6 s
# INFO:root:Starting 12 / 100, sleeping for 0.4 s
# INFO:root:Starting 9 / 100, sleeping for 0.1 s
# INFO:root:Starting 8 / 100, sleeping for 0.0 s
# INFO:root:Starting 11 / 100, sleeping for 0.3 s
# INFO:root:Starting 14 / 100, sleeping for 0.6 s
# INFO:root:Starting 12 / 100, sleeping for 0.4 s
# INFO:root:Starting 10 / 100, sleeping for 0.2 s
# INFO:root:Starting 13 / 100, sleeping for 0.5 s
# INFO:root:Starting 11 / 100, sleeping for 0.3 s
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/lib/python3.7/multiprocessing/pool.py", line 121, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-28-704e4069912f>", line 26, in model_launch
#     result = launch(config, model_seed, data_seed, model_type, "model")
#   File "<ipython-input-28-704e4069912f>", line 13, in launch
#     result = mlp_trainer(conf, evaluate = True, verbose = False, device = device)
#   File "/glade/work/schreck/repos/time-series/evidential/train_SL.py", line 471, in mlp_trainer
#     model = load_mlp_model(input_size, middle_size, output_size, dropout).to(device)
#   File "/glade/work/schreck/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 907, in to
#     return self._apply(convert)
#   File "/glade/work/schreck/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 578, in _apply
#     module._apply(fn)
#   File "/glade/work/schreck/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 601, in _apply
#     param_applied = fn(param)
#   File "/glade/work/schreck/py37/lib/python3.7/site-packages/torch/nn/modules/module.py", line 905, in convert
#     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#   File "/glade/work/schreck/py37/lib/python3.7/site-packages/torch/cuda/__init__.py", line 207, in _lazy_init
#     "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
# RuntimeError: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method
# """
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-31-bb64f89ccf4d> in <module>
#       2 model_results = []
#       3 with mp.Pool(8) as p:
# ----> 4     for result in tqdm.tqdm(p.imap(model_worker, model_seeds), total = len(model_seeds)):
#       5         model_results.append(result)
#
# /glade/work/schreck/py37/lib/python3.7/site-packages/tqdm/std.py in __iter__(self)
#    1183
#    1184         try:
# -> 1185             for obj in iterable:
#    1186                 yield obj
#    1187                 # Update and possibly print the progressbar.
#
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/lib/python3.7/multiprocessing/pool.py in next(self, timeout)
#     746         if success:
#     747             return value
# --> 748         raise value
#     749
#     750     __next__ = next                    # XXX
#
# /glade/u/apps/dav/opt/python/3.7.5/gnu/8.3.0/lib/python3.7/multiprocessing/pool.py in worker()
#     119         job, i, func, args, kwds = task
#     120         try:
# --> 121             result = (True, func(*args, **kwds))
#     122         except Exception as e:
#     123             if wrap_exception and func is not _helper_reraises_exception:
#
# <ipython-input-28-704e4069912f> in model_launch()
#      24     #time.sleep(0.1 * worker_id)
#      25     t0 = time.time()
# ---> 26     result = launch(config, model_seed, data_seed, model_type, "model")
#      27     logging.info(f"Finished {seed_id} in {time.time()-t0}")
#      28     return
#
# <ipython-input-28-704e4069912f> in launch()
#      11         yaml.dump(conf, fid)
#      12     if model_type == "mlp":
# ---> 13         result = mlp_trainer(conf, evaluate = True, verbose = False, device = device)
#      14     else:
#      15         result = trainer(conf, evaluate = True, verbose = False, device = device)
#
# /glade/work/schreck/repos/time-series/evidential/train_SL.py in mlp_trainer()
#     469
#     470
# --> 471     model = load_mlp_model(input_size, middle_size, output_size, dropout).to(device)
#     472     init_weights(model, init_type = weight_init, verbose = verbose)
#     473
#
# /glade/work/schreck/py37/lib/python3.7/site-packages/torch/nn/modules/module.py in to()
#     905             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     906
# --> 907         return self._apply(convert)
#     908
#     909     def register_backward_hook(
#
# /glade/work/schreck/py37/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply()
#     576     def _apply(self, fn):
#     577         for module in self.children():
# --> 578             module._apply(fn)
#     579
#     580         def compute_should_use_set_data(tensor, tensor_applied):
#
# /glade/work/schreck/py37/lib/python3.7/site-packages/torch/nn/modules/module.py in _apply()
#     599             # `with torch.no_grad():`
#     600             with torch.no_grad():
# --> 601                 param_applied = fn(param)
#     602             should_use_set_data = compute_should_use_set_data(param, param_applied)
#     603             if should_use_set_data:
#
# /glade/work/schreck/py37/lib/python3.7/site-packages/torch/nn/modules/module.py in convert()
#     903                 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#     904                             non_blocking, memory_format=convert_to_format)
# --> 905             return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#     906
#     907         return self._apply(convert)
#
# /glade/work/schreck/py37/lib/python3.7/site-packages/torch/cuda/__init__.py in _lazy_init()
#     205         if _is_in_bad_fork():
#     206             raise RuntimeError(
# --> 207                 "Cannot re-initialize CUDA in forked subprocess. To use CUDA with "
#     208                 "multiprocessing, you must use the 'spawn' start method")
#     209         if not hasattr(torch._C, '_cuda_getDeviceCount'):
#
# RuntimeError: Cannot re-initialize CUDA in forked subprocess. To use CUDA with multiprocessing, you must use the 'spawn' start method

# %%
df_model = pd.DataFrame.from_dict(model_results).reset_index()
df_model.to_csv(f"{save_loc}/mlp_model_ensemble_results.csv", index = False)

# %% [markdown]
# ### Create ensemble of data splits, with fixed model seed

# %%
data_worker = partial(data_launch,
                      config="config/SL-mlp.yml", 
                      model_type="mlp",
                      model_seed=model_seed)

# %%
data_results = []
with mp.Pool(8) as p:
    for result in tqdm.tqdm(p.imap(data_worker, data_seeds), total = len(data_seeds)):
        data_results.append(result)
# Out:
# INFO:root:Starting 1 / 100, sleeping for 0.1 s
# INFO:root:Starting 3 / 100, sleeping for 0.3 s
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:root:Starting 0 / 100, sleeping for 0.0 s
# INFO:root:Starting 5 / 100, sleeping for 0.5 s
# INFO:root:Starting 2 / 100, sleeping for 0.2 s
# INFO:root:Starting 4 / 100, sleeping for 0.4 s
# INFO:root:Starting 6 / 100, sleeping for 0.6 s
# INFO:root:Starting 7 / 100, sleeping for 0.7 s
# INFO:root:Finished 1 in 48.39467453956604
# INFO:root:Starting 8 / 100, sleeping for 0.0 s
# INFO:root:Finished 6 in 55.00976276397705
# INFO:root:Starting 9 / 100, sleeping for 0.1 s
# INFO:root:Finished 7 in 56.426615476608276
# INFO:root:Starting 10 / 100, sleeping for 0.2 s
# INFO:root:Finished 4 in 64.45585227012634
# INFO:root:Starting 11 / 100, sleeping for 0.3 s
# INFO:root:Finished 5 in 64.3886992931366
# INFO:root:Starting 12 / 100, sleeping for 0.4 s
# INFO:root:Finished 2 in 68.2267472743988
# INFO:root:Starting 13 / 100, sleeping for 0.5 s
# INFO:root:Finished 0 in 71.57834911346436
# INFO:root:Starting 14 / 100, sleeping for 0.6 s
#   1%|          | 1/100 [01:11<1:58:08, 71.60s/it]INFO:root:Finished 9 in 34.90119194984436
# INFO:root:Starting 15 / 100, sleeping for 0.7 s
# INFO:root:Finished 8 in 44.253451108932495
# INFO:root:Starting 16 / 100, sleeping for 0.0 s
# INFO:root:Finished 3 in 93.63615083694458
#   4%|▍         | 4/100 [01:33<31:20, 19.58s/it]  INFO:root:Starting 17 / 100, sleeping for 0.1 s
# INFO:root:Finished 10 in 51.79969072341919
# INFO:root:Starting 18 / 100, sleeping for 0.2 s
#  11%|█         | 11/100 [01:49<10:11,  6.87s/it]INFO:root:Finished 11 in 47.051368713378906
# INFO:root:Starting 19 / 100, sleeping for 0.3 s
#  12%|█▏        | 12/100 [01:52<09:21,  6.38s/it]INFO:root:Finished 13 in 46.786600828170776
# INFO:root:Starting 20 / 100, sleeping for 0.4 s
# INFO:root:Finished 14 in 58.618067264556885
# INFO:root:Starting 21 / 100, sleeping for 0.5 s
# INFO:root:Finished 12 in 80.8372540473938
#  13%|█▎        | 13/100 [02:26<15:29, 10.69s/it]INFO:root:Starting 22 / 100, sleeping for 0.6 s
# INFO:root:Finished 19 in 38.99915814399719
# INFO:root:Starting 23 / 100, sleeping for 0.7 s
# INFO:root:Finished 16 in 61.83862853050232
# INFO:root:Starting 24 / 100, sleeping for 0.0 s
# INFO:root:Finished 15 in 68.76801204681396
# INFO:root:Starting 25 / 100, sleeping for 0.1 s
#  16%|█▌        | 16/100 [02:40<11:34,  8.27s/it]INFO:root:Finished 17 in 71.2464952468872
#  18%|█▊        | 18/100 [02:45<09:09,  6.70s/it]INFO:root:Starting 26 / 100, sleeping for 0.2 s
# INFO:root:Finished 88 in 37.424331188201904
# INFO:root:Starting 94 / 100, sleeping for 0.6 s
# INFO:root:Finished 86 in 54.868614196777344
#  87%|████████▋ | 87/100 [10:30<01:10,  5.45s/it]INFO:root:Starting 95 / 100, sleeping for 0.7 s
# INFO:root:Finished 87 in 49.18406963348389
# INFO:root:Starting 96 / 100, sleeping for 0.0 s
#  88%|████████▊ | 88/100 [10:36<01:06,  5.58s/it]INFO:root:Finished 90 in 39.852269887924194
# INFO:root:Starting 97 / 100, sleeping for 0.1 s
# INFO:root:Finished 93 in 41.86614108085632
# INFO:root:Starting 98 / 100, sleeping for 0.2 s
# INFO:root:Finished 92 in 51.86804246902466
# INFO:root:Starting 99 / 100, sleeping for 0.3 s
# INFO:root:Finished 95 in 40.90569305419922
# INFO:root:Finished 89 in 80.90517330169678
#  90%|█████████ | 90/100 [11:13<01:39,  9.96s/it]INFO:root:Finished 91 in 58.54304051399231
#  92%|█████████▏| 92/100 [11:14<00:54,  6.81s/it]INFO:root:Finished 94 in 50.60542106628418
#  95%|█████████▌| 95/100 [11:17<00:22,  4.47s/it]INFO:root:Finished 96 in 44.05087232589722
#  97%|█████████▋| 97/100 [11:20<00:10,  3.65s/it]INFO:root:Finished 97 in 48.59742617607117
#  98%|█████████▊| 98/100 [11:36<00:11,  5.76s/it]INFO:root:Finished 98 in 45.03096079826355
#  99%|█████████▉| 99/100 [11:53<00:07,  7.92s/it]INFO:root:Finished 99 in 47.08987903594971
# 100%|██████████| 100/100 [11:59<00:00,  7.19s/it]

# %%
df_data = pd.DataFrame.from_dict(data_results).reset_index()
df_data.to_csv(f"{save_loc}/mlp_data_ensemble_results.csv", index = False)

# %% [markdown]
# ### Now with the evidential model

# %%
model_worker = partial(model_launch, 
                       config="config/SL.yml", 
                       model_type = "evidential", 
                       data_seed=data_seed)

# %%
#%%time
model_results = []
with mp.Pool(8) as p:
    for result in tqdm.tqdm(p.imap(model_worker, model_seeds), total = len(model_seeds)):
        model_results.append(result)
# Out:
# INFO:root:Starting 0 / 100, sleeping for 0.0 s
# INFO:root:Starting 2 / 100, sleeping for 0.2 s
# INFO:root:Starting 1 / 100, sleeping for 0.1 s
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:root:Starting 4 / 100, sleeping for 0.4 s
# INFO:root:Starting 3 / 100, sleeping for 0.3 s
# INFO:root:Starting 6 / 100, sleeping for 0.6 s
# INFO:root:Starting 5 / 100, sleeping for 0.5 s
# INFO:root:Starting 7 / 100, sleeping for 0.7 s
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:root:Finished 5 in 118.57985734939575
# INFO:root:Starting 8 / 100, sleeping for 0.0 s
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:root:Finished 1 in 134.99377369880676
# INFO:root:Starting 9 / 100, sleeping for 0.1 s
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:root:Finished 6 in 141.4270875453949
# INFO:root:Starting 10 / 100, sleeping for 0.2 s
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:root:Finished 3 in 145.86463856697083
# INFO:root:Starting 11 / 100, sleeping for 0.3 s
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:root:Finished 4 in 163.68587040901184
# INFO:root:Starting 12 / 100, sleeping for 0.4 s
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:root:Finished 7 in 171.03053641319275
# INFO:root:Starting 13 / 100, sleeping for 0.5 s
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:root:Finished
#  75%|███████▌  | 75/100 [25:16<10:38, 25.56s/it]INFO:root:Starting 86 / 100, sleeping for 0.6 s
# INFO:root:Finished 81 in 120.00379085540771
# INFO:root:Starting 87 / 100, sleeping for 0.7 s
# INFO:root:Finished 82 in 112.9688606262207
# INFO:root:Starting 88 / 100, sleeping for 0.0 s
# INFO:root:Finished 79 in 166.8571445941925
# INFO:root:Starting 89 / 100, sleeping for 0.1 s
# INFO:root:Finished 76 in 213.1857397556305
#  77%|███████▋  | 77/100 [25:34<08:15, 21.56s/it]INFO:root:Starting 90 / 100, sleeping for 0.2 s
# INFO:root:Finished 85 in 91.30294275283813
# INFO:root:Starting 91 / 100, sleeping for 0.3 s
# INFO:root:Finished 87 in 90.95082235336304
# INFO:root:Starting 92 / 100, sleeping for 0.4 s
# INFO:root:Finished 88 in 90.27666115760803
# INFO:root:Starting 93 / 100, sleeping for 0.5 s
# INFO:root:Finished 84 in 150.6347942352295
# INFO:root:Starting 94 / 100, sleeping for 0.6 s
# INFO:root:Finished 83 in 193.5825798511505
#  84%|████████▍ | 84/100 [27:32<05:03, 18.97s/it]INFO:root:Starting 95 / 100, sleeping for 0.7 s
# INFO:root:Finished 89 in 150.7579665184021
# INFO:root:Starting 96 / 100, sleeping for 0.0 s
# INFO:root:Finished 86 in 169.78298234939575
#  87%|████████▋ | 87/100 [28:07<03:42, 17.13s/it]INFO:root:Starting 97 / 100, sleeping for 0.1 s
# INFO:root:Finished 90 in 154.54141473770142
#  91%|█████████ | 91/100 [28:09<01:45, 11.78s/it]INFO:root:Starting 98 / 100, sleeping for 0.2 s
# INFO:root:Finished 91 in 137.9334967136383
#  92%|█████████▏| 92/100 [28:47<01:55, 14.49s/it]INFO:root:Starting 99 / 100, sleeping for 0.3 s
# INFO:root:Finished 94 in 112.90082216262817
# INFO:root:Finished 93 in 160.90570664405823
# INFO:root:Finished 98 in 104.50869536399841
# INFO:root:Finished 99 in 84.09235334396362
# INFO:root:Finished 95 in 172.11706066131592
# INFO:root:Finished 97 in 148.14187741279602
# INFO:root:Finished 96 in 161.3984353542328
# INFO:root:Finished 92 in 233.3354251384735
# 100%|██████████| 100/100 [30:47<00:00, 18.48s/it]

# %%
df_model = pd.DataFrame.from_dict(model_results).reset_index()
df_model.to_csv(f"{save_loc}/evidential_model_ensemble_results.csv", index = False)

# %%
data_worker = partial(data_launch, 
                      config="config/SL.yml", 
                      model_type = "evidential",
                      model_seed=model_seed)

# %%
data_results = []
with mp.Pool(8) as p:
    for result in tqdm.tqdm(p.imap(data_worker, data_seeds), total = len(data_seeds)):
        data_results.append(result)
# Out:
# INFO:root:Starting 0 / 100, sleeping for 0.0 s
# INFO:root:Starting 3 / 100, sleeping for 0.3 s
# INFO:root:Starting 1 / 100, sleeping for 0.1 s
#   0%|          | 0/100 [00:00<?, ?it/s]INFO:root:Starting 6 / 100, sleeping for 0.6 s
# INFO:root:Starting 4 / 100, sleeping for 0.4 s
# INFO:root:Starting 5 / 100, sleeping for 0.5 s
# INFO:root:Starting 7 / 100, sleeping for 0.7 s
# INFO:root:Starting 2 / 100, sleeping for 0.2 s
# INFO:numexpr.utils:Note: detected 72 virtual cores but NumExpr set to maximum of 64, check "NUMEXPR_MAX_THREADS" environment variable.
# INFO:numexpr.utils:Note: NumExpr detected 72 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# INFO:root:Finished